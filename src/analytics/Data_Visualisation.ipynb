# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file_path="data-for-datavis/fifa.csv"

# %%
fifa_dat=pd.read_csv(file_path,index_col="Date",parse_dates=True)

# %%
fifa_dat.plot()

# %%
fifa_dat.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
# pd.set_option('display.mpl_style', 'default')
plt.figure(figsize=(16,6))
sns.lineplot(data=fifa_dat)

# %%
spotify_data=pd.read_csv("data-for-datavis/spotify.csv",index_col="Date",parse_dates=True)

# %%
spotify_data.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %%
sns.lineplot(data=spotify_data)

# %%
plt.figure(figsize=(14,6))
plt.title("Daily global Streams")
sns.lineplot(data=spotify_data)

# %%
list(spotify_data.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %%
plt.figure(figsize=(14,6))
plt.title("Daily global Streams")
# sns.lineplot(data=spotify_data)
sns.lineplot(data=[spotify_data['Shape of You'],spotify_data['Something Just Like This']])
sns.lineplot(data=spotify_data["Despacito"],label="Despacto")

# %%
flightfile="data-for-datavis/flight_delays.csv"
flight_dat=pd.read_csv(flightfile,index_col="Month")

# %%
flight_dat.head(20)
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
plt.figure(figsize=(10,6))
plt.title("Average Arrival Delay for Spirit Airlines Flights, By Month")
sns.barplot(x=flight_dat.index,y=flight_dat['NK'])
plt.ylabel("Arrival delay(in minutes)")
# Out:
# Text(0, 0.5, 'Arrival delay(in minutes)')

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,7))

# Add title
plt.title("Average Arrival Delay for Each Airline, by Month")

# Heatmap showing average arrival delay for each airline by month
sns.heatmap(data=flight_dat, annot=True)

# Add label for horizontal axis
plt.xlabel("Airline")
# Out:
# Text(0.5, 42.0, 'Airline')

# %%
insfile="data-for-datavis/insurance.csv"
ins_data=pd.read_csv(insfile)

# %%
ins_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.scatterplot(x=ins_data['bmi'], y=ins_data['charges'])

# %%
sns.regplot(x=ins_data['bmi'], y=ins_data['charges'])

# %%
sns.scatterplot(x=ins_data['bmi'], y=ins_data['charges'], hue=ins_data['smoker'])
sns.lmplot(x="bmi", y="charges", hue="smoker", data=ins_data)

# %% [markdown]
#  Usually, we use scatter plots to highlight the relationship between two continuous variables (like "bmi" and "charges"). However, we can adapt the design of the scatter plot to feature a categorical variable (like "smoker") on one of the main axes. We'll refer to this plot type as a categorical scatter plot, and we build it with the sns.swarmplot command.

# %%
sns.swarmplot(x=ins_data['smoker'], y=ins_data['charges'])

# %%
iris_file="data-for-datavis/iris.csv"

# %%
iris=pd.read_csv(iris_file,index_col="Id")

# %%
iris.head(50)
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
# 6                 5.4               3.9                1.7               0.4
# 7                 4.6               3.4                1.4               0.3
# 8                 5.0               3.4                1.5               0.2
# 9                 4.4               2.9                1.4               0.2
# 10                4.9               3.1                1.5               0.1
# 11                5.4               3.7                1.5               0.2
# ...

# %%
sns.distplot(a=iris['Petal Length (cm)'], kde=False)

# %%
sns.kdeplot(data=iris['Petal Length (cm)'], shade=True)

# %% [markdown]
# # 2D KDE plots
# We're not restricted to a single column when creating a KDE plot. We can create a two-dimensional (2D) KDE plot with the sns.jointplot command.
#
# In the plot below, the color-coding shows us how likely we are to see different combinations of sepal width and petal length, where darker parts of the figure are more likely.

# %%
sns.jointplot(x=iris['Petal Length (cm)'], y=iris['Sepal Width (cm)'], kind="kde")

# %%
# Paths of the files to read
iris_set_filepath = "data-for-datavis/iris_setosa.csv"
iris_ver_filepath = "data-for-datavis/iris_versicolor.csv"
iris_vir_filepath = "data-for-datavis/iris_virginica.csv"

# Read the files into variables 
iris_set_data = pd.read_csv(iris_set_filepath, index_col="Id")
iris_ver_data = pd.read_csv(iris_ver_filepath, index_col="Id")
iris_vir_data = pd.read_csv(iris_vir_filepath, index_col="Id")

# Print the first 5 rows of the Iris versicolor data
iris_ver_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 51                7.0               3.2                4.7               1.4
# 52                6.4               3.2                4.5               1.5
# 53                6.9               3.1                4.9               1.5
# 54                5.5               2.3                4.0               1.3
# 55                6.5               2.8                4.6               1.5
#
#             Species
# Id
# 51  Iris-versicolor
# 52  Iris-versicolor
# 53  Iris-versicolor
# 54  Iris-versicolor
# 55  Iris-versicolor

# %%
# Histograms for each species
sns.distplot(a=iris_set_data['Petal Length (cm)'], label="Iris-setosa", kde=False)
sns.distplot(a=iris_ver_data['Petal Length (cm)'], label="Iris-versicolor", kde=False)
sns.distplot(a=iris_vir_data['Petal Length (cm)'], label="Iris-virginica", kde=False)

# Add title
plt.title("Histogram of Petal Lengths, by Species")

# Force legend to appear
plt.legend()

# %%
# KDE plots for each species
sns.kdeplot(data=iris_set_data['Petal Length (cm)'], label="Iris-setosa", shade=True)
sns.kdeplot(data=iris_ver_data['Petal Length (cm)'], label="Iris-versicolor", shade=True)
sns.kdeplot(data=iris_vir_data['Petal Length (cm)'], label="Iris-virginica", shade=True)

# Add title
plt.title("Distribution of Petal Lengths, by Species")
# Out:
# Text(0.5, 1.0, 'Distribution of Petal Lengths, by Species')

# %% [markdown]
# - Trends - A trend is defined as a pattern of change.
#     - sns.lineplot - Line charts are best to show trends over a period of time, and multiple lines can be used to show trends in more than one group
# - Relationship - There are many different chart types that you can use to understand relationships between variables in your data.
#     - sns.barplot - Bar charts are useful for comparing quantities corresponding to different groups.
#     - sns.heatmap - Heatmaps can be used to find color-coded patterns in tables of numbers.
#     - sns.scatterplot - Scatter plots show the relationship between two continuous variables; if color-coded, we can also show the relationship with a third categorical variable.
#     - sns.regplot - Including a regression line in the scatter plot makes it easier to see any linear relationship between two variables.
#     - sns.lmplot - This command is useful for drawing multiple regression lines, if the scatter plot contains multiple, color-coded groups.
#     - sns.swarmplot - Categorical scatter plots show the relationship between a continuous variable and a categorical variable.
# - Distribution - We visualize distributions to show the possible values that we can expect to see in a variable, along with how likely they are.
#     - sns.distplot - Histograms show the distribution of a single numerical variable.
#     - sns.kdeplot - KDE plots (or 2D KDE plots) show an estimated, smooth distribution of a single numerical variable (or two numerical variables).
#     - sns.jointplot - This command is useful for simultaneously displaying a 2D KDE plot with the corresponding KDE plots for each individual variable.

# %%
# Change the style of the figure to the "dark" theme
sns.set_style("whitegrid")

# Line chart 
plt.figure(figsize=(12,6))
sns.lineplot(data=spotify_data)

# %% [markdown]
# Seaborn has five different themes: (1)"darkgrid", (2)"whitegrid", (3)"dark", (4)"white", and (5)"ticks", and you need only use a command similar to the one in the code cell above (with the chosen theme filled in) to change it.

# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Add more seaborn datavis stuff and learn matplotlib
